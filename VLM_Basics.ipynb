# %% [markdown]
# # 1. OpenAI VLM (GPT) - Basics
# This section demonstrates the basic usage of OpenAI's Vision Language Model (VLM) capabilities using GPT-4.1.
# We will use the OpenAI API to analyze an image and provide detailed textual insights.
#
# **Support Material**
#
# - https://platform.openai.com/docs/quickstart
# - https://platform.openai.com/docs/guides/text
# - https://platform.openai.com/docs/guides/images-vision?api-mode=chat
# - https://platform.openai.com/docs/guides/structured-outputs

# %%
import openai
from dotenv import load_dotenv  
import base64
import json
import textwrap

# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')


load_dotenv()
openAIclient = openai.OpenAI()


# Path to your image
img = "images/street_scene.jpg"

# %%
#basic call to gpt with prompt and image

completion = openAIclient.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "What's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{encode_image(img)}",
                        #"detail": "low"
                    }
                },
            ],
        }
    ],
)


# Wrap the text to a specified width

response = str(completion.choices[0].message.content)
print(textwrap.fill(response, width=120))
# Out:
# The image depicts a vibrant city street scene at a crosswalk near an intersection. There are several people engaged in
# different activities: one person is sitting on the sidewalk looking at their tablet, another individual is lying down on
# the pavement, and two people are seated on a wooden bench reading. Nearby, pigeons are walking around on the ground.
# In the street, a motorcyclist and a person riding a scooter are passing by, while a man walks playing a guitar. Several
# cars are visible, including a taxi. The background showcases tall buildings and city architecture with a mix of modern
# and older styles. The lighting suggests it might be late afternoon or early evening. Overall, the scene captures a
# dynamic urban environment with a mix of calm and movement.

# %% [markdown]
# # 1.1 Structured Output
# Here, we expand upon the VLM example to request structured outputs. This approach allows for extracting
# well-organized information from images in a machine-readable format, such as JSON.
#
# **Support Material**:
# - https://platform.openai.com/docs/guides/structured-outputs

# %%
completion = openAIclient.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "you are a careful observer. the response should be in json format"},
        {"role": "user", "content": [
                {"type": "text", "text": "Describe the image in detail"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{encode_image(img)}",
                        #"detail": "low"
                    }
                },
            ]}
    ],
    response_format={ "type": "json_object" },# NEW!!
    temperature = 0
)

returnValue = completion.choices[0].message.content

# %% [markdown]
# We parse the json in a dict structure:

# %%
output = json.loads(returnValue)
#json. loads() converts JSON strings to Python objects

# %% [markdown]
# So we can access specific infos:

# %%
output
# Out:
# {'scene': 'Urban city street intersection during daytime',
#  'background': {'buildings': [{'style': 'brick facade',
#     'windows': 'multiple, reflecting sunlight',
#     'shops': 'with green awnings and lit interiors'},
#    {'style': 'modern glass skyscrapers',
#     'height': 'tall, extending into the sky',
#     'lighting': 'sunlight reflecting off glass'},
#    {'church': {'architecture': 'classic with a steeple',
#      'location': 'center background'}}],
#   'traffic': {'cars': ['white taxi with blurred motion',
#     'gray SUV',
#     'orange sedan',
#     'other cars in distance'],
#    'motorcycles': [{'rider': 'wearing black jacket and white helmet',
#      'motion': 'moving across crosswalk'},
#     {'rider': 'wearing helmet and casual clothes', 'vehicle': 'scooter'}],
#    'traffic_light': {'color': 'yellow', 'position': 'top right corner'}}},
#  'foreground': {'people': [{'position': 'left side sitting on sidewalk',
#     'activity': 'using a smartphone',
#     'clothing': 'green jacket, shorts, sneakers'},
#    {'position': 'lying on sidewalk',
#     'clothing': 'red hoodie, blue jeans, black sneakers',
#     'posture': 'relaxed, eyes closed'},
#    {'position': 'on wooden bench',
#     'people': [{'age': 'elderly man',
#       'clothing': 'gray suit',
#       'activity': 'resting head on hand, thoughtful'},
#      {'age': 'young woman',
#       'clothing': 'red blouse, blue jeans',
#       'activity': 'reading a newspaper'}]},
#    {'position': 'walking on crosswalk near bench',
#     'clothing': 'pink top, denim shorts, white sneakers',
#     'activity': 'looking at phone'},
#    {'position': 'walking on street',
#     'clothing': 'black jacket, black pants',
#     'activity': 'playing guitar'}],
#   'animals': {'pigeons': {'number': 7,
#     'locations': 'scattered on sidewalk and near people'}},
#   'plants': {'flower_pot': {'location': 'left side near sitting person',
#     'flowers': 'red blossoms with green leaves'}}},
#  'overall_mood': 'busy urban life with a mix of activity and relaxation, warm sunlight, dynamic movement with vehicles and pedestrians'}

# %%
output["street"]["pedestrians"]  # Access pedestrians in the street
output["background"]  # Access background elements
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 output["street"]["pedestrians"]  # Access pedestrians in the street
#       2 output["background"]  # Access background elements
#
# KeyError: 'street'

# %% [markdown]
# # JSON Schema for Controlled Structured Outputs
# In this section, we define a JSON schema for a more controlled and specific output from the model.
# Using this schema, we can ensure the model adheres to predefined data types and structures while describing images.In this case we will provide the json schema directly.

# %%
completion = openAIclient.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "you are a careful observer. the response should be in json format"},
        {"role": "user", "content": [
                {"type": "text", "text": "Describe the image in detail"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{encode_image(img)}",
                        #"detail": "low"
                    }
                },
            ]}
    ],
    response_format={
                "type": "json_schema",    
                "json_schema": {
                    "name": "img_extract",
                    "schema": {
                    "type": "object",
                    "properties": {
                        "numberOfPeople": {
                        "type":"integer",
                        "description": "The total number of people in the environment",
                        "minimum": 0
                        },
                        "atmosphere": {
                        "type": "string",
                        "description": "Description of the atmosphere, e.g., calm, lively, etc."
                        },
                        "hourOfTheDay": {
                        "type": "integer",
                        "description": "The hour of the day in 24-hour format",
                        "minimum": 0,
                        "maximum": 23
                        },
                        "people": {
                        "type": "array",
                        "description": "List of people and their details",
                        "items": {
                            "type": "object",
                            "properties": {
                            "position": {
                                "type": "string",
                                "description": "Position of the person in the environment, e.g., standing, sitting, etc."
                            },
                            "age": {
                                "type": "integer",
                                "description": "Age of the person",
                                "minimum": 0
                            },
                            "activity": {
                                "type": "string",
                                "description": "Activity the person is engaged in, e.g., reading, talking, etc."
                            },
                            "gender": {
                                "type": "string",
                                "description": "Gender of the person",
                                "enum": ["male", "female", "non-binary", "other", "prefer not to say"]
                            }
                            },
                            "required": ["position", "age", "activity", "gender"]
                        }
                        }
                    },
                    "required": ["numberOfPeople", "atmosphere", "hourOfTheDay", "people"]
                    }}},
    temperature = 0
)

returnValue = completion.choices[0].message.content

# %%
output_image_extraction = json.loads(returnValue)

# %%
output_image_extraction["people"]
# Out:
# [{'position': 'sitting on the ground near a flower pot',
#   'age': 16,
#   'activity': 'using a smartphone',
#   'gender': 'male'},
#  {'position': 'lying on the ground',
#   'age': 18,
#   'activity': 'resting or sleeping',
#   'gender': 'male'},
#  {'position': 'sitting on a bench',
#   'age': 65,
#   'activity': 'reading a newspaper',
#   'gender': 'female'},
#  {'position': 'sitting on a bench',
#   'age': 70,
#   'activity': 'thinking or resting with hand on face',
#   'gender': 'male'},
#  {'position': 'walking on the sidewalk near the bench',
#   'age': 20,
#   'activity': 'looking at a smartphone',
#   'gender': 'female'},
#  {'position': 'riding a motorcycle on the street',
#   'age': 30,
#   'activity': 'driving',
#   'gender': 'male'},
#  {'position': 'walking on the street playing a guitar',
#   'age': 25,
#   'activity': 'playing guitar',
#   'gender': 'male'},
#  {'position': 'riding a scooter on the street',
#   'age': 28,
#   'activity': 'driving',
#   'gender': 'female'},
#  {'position': 'walking on the crosswalk',
#   'age': 35,
#   'activity': 'walking',
#   'gender': 'female'},
#  {'position': 'driving a car',
#   'age': 40,
#   'activity': 'driving',
#   'gender': 'male'},
#  {'position': 'driving a car',
#   'age': 45,
#   'activity': 'driving',
#   'gender': 'male'}]

# %% [markdown]
# Alternatively:
#
#
# OpenAI SDKs for Python and JavaScript also make it easy to define object schemas using Pydantic and Zod respectively. Below, you can see how to extract information from unstructured text that conforms to a schema defined in code.

# %% [markdown]
# ```python
# from pydantic import BaseModel
#
#
# class Person(BaseModel):
#     position: str
#     age: int
#     activity: str
#     gender: str
#
#
# class ImageExtraction(BaseModel):
#     number_of_people: int
#     atmosphere: str
#     hour_of_the_day: int
#     people: list[Person]
#
# completion = openAIclient.beta.chat.completions.parse(
#     model="gpt-4.1-mini",
#     messages=[
#         {"role": "system", "content": "you are a careful observer. the response should be in json format"},
#         {"role": "user", "content": "describe the image in detail"}
#     ],
#     response_format=ImageExtraction,
# )
#
# output_image_extraction = completion.choices[0].message.parsed

# %% [markdown]
# We can then integrate the extracted information in full or partially in a new prompt for a new extraction

# %%
#alert service prompt 

alert_sys_prompt = " you are an experienced first aid paramedical"
alert_prompt= """Extract from the following scene analysis give to you in json format, 
if anyone might be in danger and if the Child Hospital or normal Hospital should be alerted. 
Give the a concise answer
The situation is given to you from this object: """ + str(output_image_extraction)

# %%
completion = openAIclient.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "user", "content": alert_prompt},
        {"role": "user", "content": alert_prompt}
    ],
)


# Wrap the text to a specified width

response = str(completion.choices[0].message.content)
print(textwrap.fill(response, width=120))
# Out:
# No one appears to be in immediate danger. The person lying on the ground (age 18) seems to be resting or sleeping
# without signs of distress. Therefore, no hospital alert is necessary at this time. If needed, a normal hospital would be
# appropriate, as no children (under 18) require attention.

# %%
completion = openAIclient.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Considering this list of people"+str(output_image_extraction["people"])+".Identify the youngest in the picture I provide and give me back their coordinates. The box_2d should be [ymin, xmin, ymax, xmax] normalized to 0-1000."},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{encode_image(img)}",
                        #"detail": "low"
                    }
                },
            ],
        }
    ],
)


# Wrap the text to a specified width

response = str(completion.choices[0].message.content)
print(textwrap.fill(response, width=120))
# Out:
# The youngest person in the list is a 16-year-old male sitting on the ground near a flower pot using a smartphone.
# Looking at the image, he is the person sitting on the ground in the bottom-right part of the image, interacting with a
# smartphone or tablet device.  Their approximate normalized coordinates in [ymin, xmin, ymax, xmax] format, scaled
# 0-1000, are:  [820, 220, 950, 330]

# %% [markdown]
# # 2. Google VLM (Gemini)
# This section demonstrates the use of Google's Vision Language Model, Gemini.
# We explore basic text generation as well as its ability to analyze images and provide relevant outputs.
#
# **Support Material**:
# - https://ai.google.dev/gemini-api/docs/quickstart
# - https://ai.google.dev/gemini-api/docs/text-generation
# - https://ai.google.dev/gemini-api/docs/image-understanding
# - https://ai.google.dev/gemini-api/docs/structured-output?example=recipe

# %%
from dotenv import load_dotenv
from google import genai
from PIL import Image
import textwrap

import json


load_dotenv()
client = genai.Client()

# Path to your image
img = "images/street_scene.jpg"

# %% [markdown]
# Basic call:

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works to a 90 years old. in few words"
)

print(textwrap.fill(response.text, width=120))
# Out:
# Imagine a very fast, very clever assistant.  You show it millions of examples – like pictures of cats, or answers to
# questions.  It learns to spot patterns, then it can make smart guesses or do tasks for you, almost like thinking.

# %% [markdown]
# and with images:

# %%
im = Image.open(img)

response = client.models.generate_content(model="gemini-2.5-flash",
                                          contents=[im, "Describe the scene in details\n"],
                                          )

print(textwrap.fill(response.text, width=120))
# Out:
# This image captures a vibrant and bustling urban street scene, bathed in warm, possibly late afternoon or early morning
# sunlight that casts long shadows. The composition is rich with human activity, diverse architecture, and elements of
# daily city life.  In the **immediate foreground**, on the left side of the sidewalk, a large terra cotta pot holds a
# lush plant with bright red flowers, adding a touch of nature to the concrete environment. Nearby, a young person with
# short hair sits cross-legged on the pavement, engrossed in a tablet or smartphone. Just to their right, another young
# person is lying flat on their back on the sidewalk, dressed in a red hoodie and jeans, looking relaxed or perhaps
# resting. Several pigeons are scattered around these individuals, pecking at the ground.  To the right of the foreground,
# a traditional wooden park bench with dark metal arms is occupied by two people. An older man in a dark suit sits
# pensively, with one hand supporting his chin and spectacles perched on his nose. Next to him, a woman with blonde hair,
# wearing a striped reddish-brown top and blue jeans, is intently reading a newspaper or book. Further to the right, a
# young woman in light denim shorts and a pink-striped t-shirt walks away from the bench, carrying a small tray or plate.
# More pigeons are seen near the bench, some even appearing to walk on the bench's armrest.  The **midground** features a
# busy street with a prominent zebra crosswalk. The street is a dynamic space with vehicles and pedestrians in motion. A
# silver sedan with a taxi sign on its roof and a circular emblem on its side is captured in motion blur as it crosses the
# street from left to right. Behind it, a gold-colored SUV or car is also blurred, indicating movement. A person on a
# small, dark motorcycle, wearing a white helmet and black leather jacket, is actively riding across the crosswalk from
# left to right. Beside them, a man wearing a dark hat and jacket is walking across the street, carrying and seemingly
# playing an acoustic guitar. Further right, another person on a white moped or scooter is also crossing.  The
# **background** reveals a classic city skyline and streetscape. On the left, multi-story brick buildings with large
# windows and some with green awnings line the street. These older structures give way to modern skyscrapers, their glass
# facades reflecting the golden sunlight. The street stretches far into the distance, flanked by more buildings and hints
# of distant traffic and pedestrians. A traffic light signal hangs overhead, currently showing yellow. The sun's warm glow
# illuminates the scene from the right, creating highlights on the buildings and people, and casting long shadows across
# the street and sidewalks. The overall impression is one of a lively urban setting where diverse activities and lives
# intersect amidst constant movement.

# %% [markdown]
# Also here we can extract structured output (Gemini actually prefers pydantic syntax - let's see what happens with a schema as before)-> check limitations in https://ai.google.dev/gemini-api/docs/structured-output?example=recipe

# %%
json_schema = {
                    "name": "img_extract",
                    "schema": {
                    "type": "object",
                    "properties": {
                        "numberOfPeople": {
                        "type":"integer",
                        "description": "The total number of people in the environment",
                        "minimum": 0
                        },
                        "atmosphere": {
                        "type": "string",
                        "description": "Description of the atmosphere, e.g., calm, lively, etc."
                        },
                        "hourOfTheDay": {
                        "type": "integer",
                        "description": "The hour of the day in 24-hour format",
                        "minimum": 0,
                        "maximum": 23
                        },
                        "people": {
                        "type": "array",
                        "description": "List of people and their details",
                        "items": {
                            "type": "object",
                            "properties": {
                            "position": {
                                "type": "string",
                                "description": "Position of the person in the environment, e.g., standing, sitting, etc."
                            },
                            "age": {
                                "type": "integer",
                                "description": "Age of the person",
                                "minimum": 0
                            },
                            "activity": {
                                "type": "string",
                                "description": "Activity the person is engaged in, e.g., reading, talking, etc."
                            },
                            "gender": {
                                "type": "string",
                                "description": "Gender of the person",
                                "enum": ["male", "female", "non-binary", "other", "prefer not to say"]
                            }
                            },
                            "required": ["position", "age", "activity", "gender"]
                        }
                        }
                    },
                    "required": ["numberOfPeople", "atmosphere", "hourOfTheDay", "people"]}}



config={
        "response_mime_type": "application/json",
        "response_json_schema": json_schema,
    }


response = client.models.generate_content(model="gemini-2.5-flash",
                                          contents=[im, "Describe the scene in details, follwoing exactly the given json schema\n"],
                                          config=config
                                          )



print(response.text)
# Out:
# {
#   "description": "A bustling and vibrant city street scene captured from a slightly elevated perspective, showcasing a diverse group of people engaged in various activities, alongside moving vehicles and pigeons on the sidewalk. The architecture ranges from classic brick buildings to modern skyscrapers, illuminated by warm, golden light.",
#   "people": [
#     "The image features a young male sitting cross-legged on the left foreground sidewalk, wearing a green jacket and light shorts, engrossed in a tablet. Next to him, a young adult male lies flat on his back on the sidewalk in the center foreground, clad in a red hoodie and blue jeans, surrounded by pigeons. Crossing the street in the mid-ground are a male motorcyclist in a black leather jacket and white helmet, a male musician walking and playing an acoustic guitar, and a female riding a white scooter. On a wooden bench to the right, an elderly male in a grey suit sits thoughtfully, while a female in a striped red and orange top reads a newspaper. In the right background, a young adult female walks on the crosswalk, holding a white plate or tray, wearing a pink t-shirt and denim shorts. Various other blurred pedestrians are visible on the sidewalks in the background."
#   ],
#   "vehicles": [
#     "A silver sedan with a yellow taxi sign is captured with motion blur as it crosses the street in the left foreground. Behind it, a silver SUV appears to be stationary or moving slowly. A gold sedan also shows motion blur further back on the street. A black motorcycle is ridden across the crosswalk by a man, and a white/light grey scooter is ridden by a woman. A silver sedan is parked on the street in the right background. Numerous indistinct cars are visible in the distant background of the city street."
#   ],
#   "animals": [
#     "Approximately eight pigeons are scattered across the sidewalk in the foreground and midground, some near the man lying down and the bench."
#   ],
#   "objects": [
#     "A yellow traffic light hangs over the street in the upper right. A grey metal street light pole stands in the left midground. A white striped crosswalk stretches across the street. A brown wooden slatted bench with black metal supports is situated on the right sidewalk. A large wooden pot filled with red and orange flowers is on the left foreground sidewalk. A dark tablet is held by the boy on the curb. An acoustic guitar is played by the walking musician. A newspaper or magazine is read by the woman on the bench. A white plate or tray is held by the walking woman in the background."
#   ],
#   "background": "The background consists of a vibrant urban landscape. On the left and right, multi-story brick buildings with numerous windows line the street. In the center, a cluster of modern glass skyscrapers rises prominently, with a distinct old church-like building featuring a spire situated among them. The street is paved with asphalt, and the sidewalks are concrete. Green trees are visible along the sidewalks, particularly on the right side. The sky in the distance has a warm, golden glow, suggesting either sunrise or sunset.",
#   "dominant_colors": [
#     "brown",
#     "grey",
#     "blue",
#     "red",
#     "orange",
#     "black",
#     "white",
#     "gold"
#   ],
#   "lighting": "The scene is illuminated by warm, golden hour lighting, indicative of either a sunrise or sunset. This light creates long, distinct shadows and bathes the buildings and figures in a soft, glowing hue.",
#   "mood": "The mood is lively, bustling, and urban, characterized by a mix of everyday city life and slightly unusual occurrences, creating an eclectic and dynamic atmosphere. There's a subtle sense of surrealism due to some of the specific actions of the people."
# }

# %% [markdown]
# Does it match your schema?

# %% [markdown]
# Let's try to use Gemini to detect an object in the image and get its coordinates:

# %%
prompt = "Identify the youngest in the picture and give me back their coordinates. The box_2d should be [ymin, xmin, ymax, xmax] normalized to 0-1000."


config={"response_mime_type": "application/json"}

response = client.models.generate_content(model="gemini-2.5-flash",
                                          contents=[img, prompt],
                                          config=config
                                          )

bounding_boxes = json.loads(response.text)
print(bounding_boxes)
# Out:
# {'youngest_person_coordinates': [625, 300, 1000, 400]}

# %% [markdown]
# Gemini2+ was trained specifically for object detection/ segmentation tasks. More details: https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb

# %% [markdown]
# ## 3.Extract Structured Infos from Hand-written note - GPT & Gemini

# %% [markdown]
# Let’s try **not** to extract structured information from a handwritten note (e.g., `prescription1.jpg`) using **both models**.
#
# Consider the file: `/images/prescription1.jpg`.
# Have a look at it.
#
# ### JSON Schema
# Let’s define a JSON schema for the extraction task:

# %%
json_schema_prescription = {
 "name": "prescription_extract",
"schema": {
  "type": "object",
  "properties": {
    "doctor_name": { "type": "string" },
    "patient_name": { "type": "string" },
    "patient_dob": { "type": "string" },
    "meds": {
      "type": "array",
      "items": {
        "type": "object",
        "properties": {
          "name": { "type": "string" },
          "dose": { "type": "string" },
          "frequency": { "type": "string" },
          "instructions": { "type": "string" }
        },
        "required": ["name"]
      }
    },
    "signature": { "type": "boolean" }
  },
  "required": ["doctor_name", "patient_name", "meds"]
}}

# %% [markdown]
# Extract structured infos using Gemini:

# %%
im = Image.open("images/prescription1.jpg")

config={
        "response_mime_type": "application/json",
        "response_json_schema": json_schema_prescription,
    }


response = client.models.generate_content(model="gemini-2.5-flash",
                                          contents=[im, "Extract infos from image, follwoing the given json schema.\n"],
                                          config=config
                                          )



print(response.text)
# Out:
# {"patient_details": "Claudia Fischer, 2.4.1978 (f)", "doctor_details": "Dr. Markus Mütter, Chury", "medication_details": "Ibuprofen 3x 400mg (nach dem Essen)", "signature": true}

# %% [markdown]
# If the output is **not valid JSON** and contains extra strings, it must be **parsed** before it can be loaded into a Python dict.
# Below is an example helper function that does this.
#
# > **Note:** Since Gemini returns a Pydantic model, you *could* use Pydantic methods to handle parsing.
# > We avoid that here to keep the workflow generally compatible across models.

# %%
import re
import json 
def parse_json_in_output(output):
    """
    Extracts and converts JSON-like data from the given text output to a Python dictionary.
    
    Args:
        output (str): The text output containing the JSON data.
    
    Returns:
        dict: The parsed JSON data as a Python dictionary.
    """
    # Regex to extract JSON-like portion
    json_match = re.search(r"\{.*?\}", output, re.DOTALL)
    if json_match:
        json_str = json_match.group(0)
        # Fix single quotes and ensure proper JSON formatting
        json_str = json_str.replace("'", '"')  # Replace single quotes with double quotes
        try:
            # Convert the fixed JSON string into a dictionary
            json_data = json.loads(json_str)
            return json_data
        except json.JSONDecodeError:
            return "The extracted JSON is still not valid after formatting."
    else:
        return "No JSON data found in the given output."

# %%
#print(parse_json_in_output(response.text))

# %%
json.loads(response.text)
# Out:
# {'patient_details': 'Claudia Fischer, 2.4.1978 (f)',
#  'doctor_details': 'Dr. Markus Mütter, Chury',
#  'medication_details': 'Ibuprofen 3x 400mg (nach dem Essen)',
#  'signature': True}

# %% [markdown]
# Now let's do the same with GPT

# %%
im = "images/prescription1.jpg"

completion = openAIclient.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "you are a careful observer. the response should be in json format"},
        {"role": "user", "content": [
                {"type": "text", "text": "Describe the image in detail"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{encode_image(im)}",
                        #"detail": "low"
                    }
                },
            ]}
    ],
    response_format={
                "type": "json_schema",   "json_schema": json_schema_prescription},
    temperature = 0
)

returnValue = completion.choices[0].message.content

# %%
returnValue
# Out:
# '{"doctor_name":"Dr. Markus Müller","patient_name":"Claudia Fischer","patient_dob":"1.4.1978","meds":[{"name":"Ibuprofen","dose":"400 mg","frequency":"3x","instructions":"nach dem Essen"}],"signature":true}'

# %% [markdown]
# Any difference wiht the output of Gemini vs your schema?
#
# No need for parsing now. We load the json in a python dict structure with json.loads

# %%
print(json.loads(returnValue))
# Out:
# {'doctor_name': 'Dr. Markus Müller', 'patient_name': 'Claudia Fischer', 'patient_dob': '1.4.1978', 'meds': [{'name': 'Ibuprofen', 'dose': '400 mg', 'frequency': '3x', 'instructions': 'nach dem Essen'}], 'signature': True}
